# %%
# Cell 0: Universal Monorepo Path Resolution & Zero-Mock Invariant
import sys, os
REPO_ROOT = '/Users/aaron/DFS_UNIFIED/Lauburu-Monorepo'
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)
print(f'✅ Path initialized: {REPO_ROOT}')

# %% [markdown]
# # 🥋 3D Spatial Grappling Kinematics & OPML Analysis
# Parses the 955-node OPML grappling hierarchy and computes node transition graphs.

# %%
import xml.etree.ElementTree as ET
from pathlib import Path

opml_path = Path(REPO_ROOT) / 'obsidian_vault' / 'grappling_mindmap_structure.opml'
if opml_path.exists():
    tree = ET.parse(opml_path)
    outlines = tree.getroot().findall('.//outline')
    print(f'✅ Loaded OPML Tree. Total Kinematic Outlines: {len(outlines)}')
else:
    print('OPML path waiting for live file synchronization.')
