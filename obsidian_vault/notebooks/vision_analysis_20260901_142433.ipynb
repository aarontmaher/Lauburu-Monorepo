# %%
# Cell 0: Universal Monorepo Path Resolution & Zero-Mock Invariant
import sys, os
REPO_ROOT = '/Users/aaron/DFS_UNIFIED/Lauburu-Monorepo'
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)
print(f'✅ Path initialized: {REPO_ROOT}')

# %% [markdown]
# # 👁️ Screen Lens Multimodal Perception & Hermes 3 Action Trajectories
# Queries local SQLite OCR database and extracts temporal window contexts.

# %%
import sqlite3, os
db_path = os.path.expanduser('~/.lauburu/screen_lens.sqlite')
if os.path.exists(db_path):
    conn = sqlite3.connect(f'file:{db_path}?mode=ro', uri=True)
    count = conn.execute('SELECT count(*) FROM captures').fetchone()[0]
    conn.close()
    print(f'✅ Screen Lens Indexed OCR Captures: {count}')
else:
    print('Screen Lens DB offline or standby.')
